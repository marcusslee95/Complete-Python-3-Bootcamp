# %% [markdown]
# # Milestone Project 2 - Walkthrough Steps Workbook
# Below is a set of steps for you to follow to try to create the Blackjack Milestone Project game!

# %% [markdown]
# ## Game Play
# To play a hand of Blackjack the following steps must be followed:
# 1. Create a deck of 52 cards
# 2. Shuffle the deck
# 3. Ask the Player for their bet
# 4. Make sure that the Player's bet does not exceed their available chips
# 5. Deal two cards to the Dealer and two cards to the Player
# 6. Show only one of the Dealer's cards, the other remains hidden
# 7. Show both of the Player's cards
# 8. Ask the Player if they wish to Hit, and take another card
# 9. If the Player's hand doesn't Bust (go over 21), ask if they'd like to Hit again.
# 10. If a Player Stands, play the Dealer's hand. The dealer will always Hit until the Dealer's value meets or exceeds 17
# 11. Determine the winner and adjust the Player's chips accordingly
# 12. Ask the Player if they'd like to play again

# %% [markdown]
# ## Playing Cards
# A standard deck of playing cards has four suits (Hearts, Diamonds, Spades and Clubs) and thirteen ranks (2 through 10, then the face cards Jack, Queen, King and Ace) for a total of 52 cards per deck. Jacks, Queens and Kings all have a rank of 10. Aces have a rank of either 11 or 1 as needed to reach 21 without busting. As a starting point in your program, you may want to <b>assign variables to store a list of suits, ranks, and then use a dictionary to map ranks to values. </b>

# %% [markdown]
# ## The Game
# ### Imports and Global Variables
# ** Step 1: Import the random module. This will be used to shuffle the deck prior to dealing. Then, declare variables to store suits, ranks and values. You can develop your own system, or copy ours below. Finally, declare a Boolean value to be used to control <code>while</code> loops. This is a common practice used to control the flow of the game.**
#
#     suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
#     ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
#     values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':10,
#              'Queen':10, 'King':10, 'Ace':11}

# %%
import random

suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':10,
             'Queen':10, 'King':10, 'Ace':11}

playing = True

print(suits)

# import random

# suits = pass
# ranks = pass
# values = pass

# playing = True
# Out:
# ('Hearts', 'Diamonds', 'Spades', 'Clubs')

# %% [markdown]
# ### Class Definitions
# <b> Consider making a Card class where each Card object has a suit and a rank, then a Deck class to hold all 52 Card objects, and can be shuffled, and finally a Hand class that holds those Cards that have been dealt to each player from the Deck.

# %% [markdown]
# **Step 2: Create a Card Class**<br>
# A Card object really only needs two attributes: suit and rank. You might add an attribute for "value" - we chose to handle value later when developing our Hand class.<br>In addition to the Card's \_\_init\_\_ method, consider adding a \_\_str\_\_ method that, when asked to print a Card, returns a string in the form "Two of Hearts"

# %%
class Card:
    
    def __init__(self, suit, rank):
        self.suit = suit
        self.rank = rank
    
    def __str__(self):
        return str(self.rank) + " of " + str(self.suit)

twoOfHearts = Card("Hearts", "Two")
print(twoOfHearts)

# class Card:
    
#     def __init__(self):
#         pass
    
#     def __str__(self):
#         pass
# Out:
# Two of Hearts

# %% [markdown]
# **Step 3: Create a Deck Class**<br>
# Here we might store 52 card objects in a list that can later be shuffled. First, though, we need to *instantiate* all <b> 1. 52 unique card objects and add them to our list. </b> So long as the Card class definition appears in our code, we can build Card objects inside our Deck \_\_init\_\_ method. Consider iterating over sequences of suits and ranks to build out each card. This might appear inside a Deck class \_\_init\_\_ method:
#
#     for suit in suits:
#         for rank in ranks:
#
# In addition to an \_\_init\_\_ method we'll want to add methods to <b> 2. shuffle our deck </b>, and to <b> 3. deal out cards </b> during gameplay.<br><br>
# OPTIONAL: We may never need to print the contents of the deck during gameplay, but having the ability to see the cards inside it may help troubleshoot any problems that occur during development. With this in mind, consider adding <b> a \_\_str\_\_ method </b> to the class definition.

# %%
class Deck:
    
    def __init__(self):
        self.deck = []  # start with an empty list
        for suit in suits:
            for rank in ranks:
                cardInDeck = Card(suit, rank)
                self.deck.append(cardInDeck)
    
    def __str__(self):
        rv = ""
        for card in self.deck:
#             rv = rv + card.rank + " of " + card.suit + ","
            rv += '\n' + card.__str__()
#             rv = rv + str(card) + ","
        return "The card has: " + rv
#         return self.deck;

    def shuffle(self):
        random.shuffle(self.deck)
        
    def deal(self):
        # turns out dealing meant just taking a card from the deck and giving it to someone else 
        cardForSomeone = self.deck.pop()
        return cardForSomeone
# #       Not sure what dealing really looks like. My idea of it: you pass out two cards to each person from the deck
#         cardOneForPlayer = self.deck.pop()
#         cardTwoForPlayer = self.deck.pop()
#         cardOneForDealer = self.deck.pop()
#         cardTwoForDealer = self.deck.pop()
# #         Now deck array will be 48 cards 
    
# class Deck:
    
#     def __init__(self):
#         self.deck = []  # start with an empty list
#         for suit in suits:
#             for rank in ranks:
#                 pass
    
#     def __str__(self):
#         pass

#     def shuffle(self):
#         random.shuffle(self.deck)
        
#     def deal(self):
#         pass

# %% [markdown]
# TESTING: Just to see that everything works so far, let's see what our Deck looks like!

# %%
test_deck = Deck()
test_deck.shuffle()
print(test_deck)
# Out:
# The card has:
# Jack of Spades
# King of Hearts
# Five of Spades
# Two of Diamonds
# Ten of Clubs
# Ten of Hearts
# Jack of Clubs
# Two of Spades
# Four of Spades
# Four of Hearts
# Nine of Diamonds
# King of Diamonds
# Ten of Diamonds
# Two of Clubs
# Seven of Spades
# Nine of Hearts
# Ace of Hearts
# Jack of Hearts
# Seven of Diamonds
# Three of Spades
# Ace of Diamonds
# Queen of Spades
# Three of Diamonds
# Six of Hearts
# Eight of Spades
# Nine of Clubs
# Five of Clubs
# Nine of Spades
# Four of Diamonds
# Queen of Diamonds
# Three of Clubs
# Five of Hearts
# Three of Hearts
# Queen of Clubs
# Eight of Clubs
# Six of Diamonds
# Eight of Hearts
# Six of Spades
# Two of Hearts
# Eight of Diamonds
# Ten of Spades
# Queen of Hearts
# King of Spades
# Jack of Diamonds
# Four of Clubs
# Ace of Clubs
# Seven of Hearts
# Seven of Clubs
# Ace of Spades
# Six of Clubs
# Five of Diamonds
# King of Clubs

# %% [markdown]
# Great! Now let's move on to our Hand class.

# %% [markdown]
# **Step 4: Create a Hand Class**<br>
# In addition to <b> 1. holding Card objects dealt from the Deck </b> , the Hand class may be used to <b>  2. calculate the value </b> of those cards using the values dictionary defined above. It may also need to <b> 3. adjust for the value of Aces </b> when appropriate.

# %%
class Hand:
    def __init__(self):
        self.cards = []  # start with an empty list as we did in the Deck class
        self.value = 0   # start with zero value
        self.aces = 0    # add an attribute to keep track of aces
    
    def add_card(self,card):
        self.cards.append(card) #add to hand
        self.value += values[card.rank] #update value as normally would
        if (card.rank == 'Ace'):
            self.aces += 1 
    
    def adjust_for_ace(self):
#         if total value > 21 and I still have an ace then change my ace to be a 1 instead of an 11
        while self.value > 21 and self.aces > 0: 
            self.value -= 10
            selfaces -= 1
        
# PURELY MY IMPLEMENTATION 
# class Hand:
#     def __init__(self):
#         self.cards = []  # start with an empty list as we did in the Deck class
#         self.value = 0   # start with zero value
#         self.aces = 0    # add an attribute to keep track of aces
    
#     def add_card(self,card):
#         self.cards.append(card) #add to hand 
#         if (card.rank == 'Ace'): #update value appropriately to situation when card is an ace 
#             self.aces += 1
#             self.adjust_for_ace()
#         else:
#             self.value += values[card.rank] #update value as normally would
    
#     def adjust_for_ace(self):
#         if (21 - self.value >= 11):
#             self.value += 11
#         else: 
#             self.value += 1
    
# class Hand:
#     def __init__(self):
#         self.cards = []  # start with an empty list as we did in the Deck class
#         self.value = 0   # start with zero value
#         self.aces = 0    # add an attribute to keep track of aces
    
#     def add_card(self,card):
#         pass
    
#     def adjust_for_ace(self):
#         pass

# %%
#Testing
test_deck = Deck() 
test_deck.shuffle()
pulledCard = test_deck.deal()
print(pulledCard)
myHand = Hand()
myHand.add_card(pulledCard)
print(myHand.value)

# #Testing my implementation - esp. if adjusting for ace is working 
# sampleHand = Hand()
# sampleCard = Card("Hearts", "Two")
# sampleHand.add_card(sampleCard)
# print(str(sampleHand.value))
# sampleCard = Card("Hearts", "Ace")
# sampleHand.add_card(sampleCard)
# print(str(sampleHand.value))
# sampleCard = Card("Hearts", "Ace")
# sampleHand.add_card(sampleCard)
# print(str(sampleHand.value))
# for card in sampleHand.cards: 
#     print(card)
# Out:
# Ace of Spades
# 11

# %% [markdown]
# **Step 5: Create a Chips Class**<br>
# In addition to decks of cards and hands, we need to keep track of a Player's starting chips, bets, and ongoing winnings. This could be done using global variables, but in the spirit of object oriented programming, let's make a Chips class instead!

# %%
class Chips:
    
    def __init__(self):
        self.total = 100  # This can be set to a default value or supplied by a user input
        self.bet = 0
        
    def win_bet(self):
        self.total += self.bet #win what you bet 
    
    def lose_bet(self):
        self.total -= self.bet


# class Chips:
    
#     def __init__(self):
#         self.total = 100  # This can be set to a default value or supplied by a user input
#         self.bet = 0
        
#     def win_bet(self):
#         pass
    
#     def lose_bet(self):
#         pass

# %%
# Testing 
sampleChips = Chips()
sampleChips.bet = 7
sampleChips.win_bet()
print(sampleChips.total)
sampleChips.bet = 100
sampleChips.lose_bet()
print(sampleChips.total)
# Out:
# 107
# 7

# %% [markdown]
# ### Function Defintions
# A lot of steps are going to be repetitive. That's where functions come in! The following steps are guidelines - add or remove functions as needed in your own program.

# %% [markdown]
# **Step 6: Write a function for taking bets**<br>
# Since we're asking the user for an integer value, this would be a good place to use <code>try</code>/<code>except</code>. Remember to check that a Player's bet can be covered by their available chips.

# %%
def take_bet(chips):
    
    while True:
        try:
            chips.bet = int(input('How many chips would you like to bet? '))
        except ValueError:
            print('Sorry, a bet must be an integer!')
        else:
            if chips.bet > chips.total:
                print("Sorry, your bet can't exceed",chips.total)
            else:
                break
# def take_bet(someChipInstance):
#     #1. take user input
#     userBet = input("Please enter your bet: ")
    
#     #2. inspecting input to see if it's valid 
#     userHasNotInputProperBet = True
#     while userHasNotInputProperBet:
#         # what to do if input is incorrect (1. it's not a # 2. it's more than chips user has)
#         if (type(userBet) !=  int or userBet >  someChipInstance.total): 
#             #ask user to input again 
#             userBet = input("Please enter a proper bet: ")
#         else: 
#             userHasNotInputProperBet = False
    
#     #3. change chip instance's bet property to user input 
#     someChipInstance.bet = userBet


# def take_bet():
    
#     pass

# %%
type(8)
if type(8) == int:
    print('works')

#TESTING THE FUNCTION 
myChips = Chips()
take_bet(myChips)
print(myChips.bet)
# Out:
# works
# How many chips would you like to bet? 1
# 1

# %% [markdown]
# **Step 7: Write a function for taking hits**<br>
# Either player can take hits until they bust. This function will be called during gameplay anytime a Player requests a hit, or a Dealer's hand is less than 17. It should take in Deck and Hand objects as arguments, and deal one card off the deck and add it to the Hand. You may want it to check for aces in the event that a player's hand exceeds 21.

# %%
def hit(deck,hand):
#                             - What should change when take hit function executes:
#                             - 1. Deck - loses a card
#                             - 2. Hand - adds a card 
#                             - 3. Update total value in Hand (if it’s an ace then run ifAce method)
#                             - 4. If dealer then keep hitting if it’s < 17 and < user 

#                             - 1. Deck - loses a card
    cardPersonGets = deck.deal() 
#                             - 2. Hand - adds a card
#                             - 3. Update total value in Hand (if it’s an ace then run ifAce method)
    hand.add_card(cardPersonGets)
    hand.adjust_for_ace() #the idea with adjust_for_ace() method <- whenever add a card to the hand if
        #it's an ace then do as you normally would adding the value (aka. 11) 
        #but then check if it's an ace each time you added and run the adjust_for_ace() method if it is 

#                             - 4. (THINK TEACHER LEFT THIS PART FOR OUTSIDE THE FUNCTION) If dealer then keep hitting if it’s < 17 and < user 
    
# def hit(deck,hand):
    
#     pass

# %%
a_deck = Deck()
a_deck.shuffle()
a_hand = Hand() 
hit(a_deck,a_hand)
for card in a_hand.cards:
    print(card)
print(a_hand.value,a_hand.aces)
# Out:
# Five of Spades
# 5 0

# %% [markdown]
# **Step 8: Write a function prompting the Player to Hit or Stand**<br>
# This function should accept the deck and the player's hand as arguments, and assign playing as a global variable.<br>
# If the Player Hits, employ the hit() function above. If the Player Stands, set the playing variable to False - this will control the behavior of a <code>while</code> loop later on in our code.

# %%
def hit_or_stand(deck,hand):
    global playing  # to control an upcoming while loop
    
    while True:
        x = input("Would you like to Hit or Stand? Enter 'h' or 's' ")
        
        if x[0].lower() == 'h':
            hit(deck,hand)  # hit() function defined above

        elif x[0].lower() == 's':
            print("Player stands. Dealer is playing.")
            playing = False

        else:
            print("Sorry, please try again.")
            continue
        break
        
        
# def hit_or_stand(deck,hand):
#     global playing  # to control an upcoming while loop
    
#     while True: 
#         userAnswer = input('Hit or stand? Enter h or s')
#         if userAnswer[0].lower() == 'h': 
#             hit(deck,hand)
#         elif userAnswer[0].lower() =='s':
#             print('Player stands dealer turn')
#             playing = False 
#         else: 
#             print('Sorry did not understand. Please enter h or s only')
            
#         break #if none of the above got triggered... i'm confused cuz 
#         #even if you entered invalid input you break from loop so don't ask for input againn....
        
# def hit_or_stand(deck,hand):
#     global playing  # to control an upcoming while loop
    
#     pass

# %% [markdown]
# **Step 9: Write functions to display cards**<br>
# When the game starts, and after each time Player takes a card, the dealer's first card is hidden and all of Player's cards are visible. At the end of the hand all cards are shown, and you may want to show each hand's total value. Write a function for each of these scenarios.

# %%
def show_some(player,dealer):
    print('Dealer starting hand')
    print(dealer.cards[1])
    print('\n')
    print('Player starting hand')
    for card in player.cards:
        print(card)
    
def show_all(player,dealer):
    print('Dealer ending hand')
    for card in dealer.cards:
        print(card)
    print('\n')
    print('Player ending hand')
    for card in player.cards:
        print(card)

# def show_some(player,dealer):
    
#     pass
    
# def show_all(player,dealer):
    
#     pass

# %% [markdown]
# **Step 10: Write functions to handle end of game scenarios**<br>
# Remember to pass player's hand, dealer's hand and chips as needed.

# %%
def player_busts(player, dealer, chips):
    chips.lose_bet()
    print ('Player lost')

def player_wins(player, dealer, chips):
    chips.win_bet()
    print ('Player lost')

def dealer_busts(player, dealer, chips):
    chips.win_bet()
    print('Dealer lost. Player wins')
    
def dealer_wins(player, dealer, chips):
    chips.lose_bet()
    print ('Dealer wins. Player lost')
    
def push(player, dealer, chips): #Tie
    print ('its a tie. No change in chips')

# %% [markdown]
# ### And now on to the game!!

# %%
while True:
    # Print an opening statement
    print('Welcome to BlackJack! Get as close to 21 as you can without going over!\n\
    Dealer hits until she reaches 17. Aces count as 1 or 11.')
    
    # Create & shuffle the deck, deal two cards to each player
    deck = Deck()
    deck.shuffle()
    
    player_hand = Hand()
    player_hand.add_card(deck.deal())
    player_hand.add_card(deck.deal())
    
    dealer_hand = Hand()
    dealer_hand.add_card(deck.deal())
    dealer_hand.add_card(deck.deal())
            
    # Set up the Player's chips
    player_chips = Chips()  # remember the default value is 100    
    
    # Prompt the Player for their bet
    take_bet(player_chips)
    
    # Show cards (but keep one dealer card hidden)
    show_some(player_hand,dealer_hand)
    
    while playing:  # recall this variable from our hit_or_stand function
        
        # Prompt for Player to Hit or Stand
        hit_or_stand(deck,player_hand) 
        
        # Show cards (but keep one dealer card hidden)
        show_some(player_hand,dealer_hand)  
        
        # If player's hand exceeds 21, run player_busts() and break out of loop
        if player_hand.value > 21:
            player_busts(player_hand,dealer_hand,player_chips)
            break        


    # If Player hasn't busted, play Dealer's hand until Dealer reaches 17 
    if player_hand.value <= 21:
        
        while dealer_hand.value < 17:
            hit(deck,dealer_hand)    
    
        # Show all cards
        show_all(player_hand,dealer_hand)
        
        # Run different winning scenarios
        if dealer_hand.value > 21:
            dealer_busts(player_hand,dealer_hand,player_chips)

        elif dealer_hand.value > player_hand.value:
            dealer_wins(player_hand,dealer_hand,player_chips)

        elif dealer_hand.value < player_hand.value:
            player_wins(player_hand,dealer_hand,player_chips)

        else:
            push(player_hand,dealer_hand)        
    
    # Inform Player of their chips total 
    print("\nPlayer's winnings stand at",player_chips.total)
    
    # Ask to play again
    new_game = input("Would you like to play another hand? Enter 'y' or 'n' ")
    
    if new_game[0].lower()=='y':
        playing=True
        continue
    else:
        print("Thanks for playing!")
        break
        
        
# while True:
#     # Print an opening statement
#     print('Welcome to the Ghetto Blackjack Game')
    
#     # Create & shuffle the deck, deal two cards to each player
#     game_deck = Deck() 
#     game_deck.shuffle() 
    
#     player = Hand()
#     player.add_card(game_deck.deal())
#     player.add_card(game_deck.deal())
#     # shouldn't we adjust for ace cuz what if player got two aces?
#     dealer = Hand() 
#     dealer.add_card(game_deck.deal())
#     dealer.add_card(game_deck.deal())
        
#     # Set up the Player's chips
#     player_chips = Chips()
    
    
#     # Prompt the Player for their bet
#     take_bet(player_chips)
    
#     # Show cards (but keep one dealer card hidden)
#     show_some(player,dealer)
    
#     while playing:  # recall this variable from our hit_or_stand function
        
#         #My comment: This is player's turn
#         # Prompt for Player to Hit or Stand
#         hit_or_stand(game_deck,player)
        
#         # Show cards (but keep one dealer card hidden) <- ****do this because if player hit they just got another card
#         show_some(player,dealer)
        
#         # If player's hand exceeds 21, run player_busts() and break out of loop ***AKA NO LONGER PLAYER TURN
#         if (player.value > 21): 
#             player_busts(player, dealer, player_chips)
#             break

#     # If Player hasn't busted play Dealer's hand until Dealer reaches 17  <- 
#     #**that's cuz IF PLAYER BUSTED DEALER DOESN'T HAVE TO PLAY SO CAN SKIPP ALL THIS
#     if player.value <= 21: 
#         while dealer.value < 17: 
#             hit(game_deck, dealer)
    
#         # Show all cards **cuz everyone's finished hitting now just have to compare. 
#         show_all(player,dealer)
#         # Run different winning scenarios
#         if dealer.value > 21: 
#             dealer_busts(player, dealer, player_chips)
#         elif dealer.value > player.value: 
#             dealer_wins(player, dealer, player_chips)
#         elif dealer.value < player.value: 
#             player_wins(player, dealer, player_chips)
#         else: #covered all other cases 
#             push(player, dealer, player_chips)
    
#     # Inform Player of their chips total 
#     print('\n Player total chips: ') 
#     print(player_chips.total) 
#     # Ask to play again
#     new_game = input('would u like to play another hand? y/n') 
#     if new_game[0].lower() =='y': 
#         playing = True 
#         continue #**keeps going onto next iteration of loop  
#     else: 
#         print('thanks for playing!') 
#         break #**breaks out of loop 
        
        
        
        
# while True:
#     # Print an opening statement

    
#     # Create & shuffle the deck, deal two cards to each player

    
        
#     # Set up the Player's chips
    
    
#     # Prompt the Player for their bet

    
#     # Show cards (but keep one dealer card hidden)

    
#     while playing:  # recall this variable from our hit_or_stand function
        
#         # Prompt for Player to Hit or Stand
        
        
#         # Show cards (but keep one dealer card hidden)
 
        
#         # If player's hand exceeds 21, run player_busts() and break out of loop
        

#             break

#     # If Player hasn't busted, play Dealer's hand until Dealer reaches 17
    
    
#         # Show all cards
    
#         # Run different winning scenarios
        
    
#     # Inform Player of their chips total 
    
#     # Ask to play again

#         break
# Out:
# Welcome to BlackJack! Get as close to 21 as you can without going over!
#     Dealer hits until she reaches 17. Aces count as 1 or 11.
# How many chips would you like to bet? 5
# Dealer starting hand
# Jack of Hearts
#
#
# Player starting hand
# Six of Spades
# Queen of Clubs
# Would you like to Hit or Stand? Enter 'h' or 's' s
# Player stands. Dealer is playing.
# Dealer starting hand
# Jack of Hearts
#
#
# Player starting hand
# Six of Spades
# Queen of Clubs
# Dealer ending hand
# Jack of Clubs
# Jack of Hearts
#
#
# Player ending hand
# Six of Spades
# Queen of Clubs
# Dealer wins. Player lost
#
# Player's winnings stand at 95
# Would you like to play another hand? Enter 'y' or 'n' y
# Welcome to BlackJack! Get as close to 21 as you can without going over!
#     Dealer hits until she reaches 17. Aces count as 1 or 11.
# How many chips would you like to bet? 6
# Dealer starting hand
# Ace of Diamonds
#
#
# Player starting hand
# Six of Spades
# Three of Spades
# ...

# %% [markdown]
# And that's it! Remember, these steps may differ significantly from your own solution. That's OK! Keep working on different sections of your program until you get the desired results. It takes a lot of time and patience! As always, feel free to post questions and comments to the QA Forums.
# # Good job!
